# %% [markdown]
# #### This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#EX1 ## 2วิธี
#EX1.1
import numpy as np
from scipy.interpolate import make_interp_spline
import matplotlib.pyplot as plt
 

x = np.array([0,1.6,3,4.9,7.9,9,10])
y = np.array([0,1,0,-1,1,0.25,-0.5])
 
X_Y_Spline = make_interp_spline(x, y)

X_ = np.linspace(x.min(), x.max(), 500)
Y_ = X_Y_Spline(X_)

plt.plot(X_, Y_)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
#EX1.2
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(0, 3.5 * np.pi, 100)
Ya = np.sin(X)


plt.plot(X, Ya)

plt.show()

# %%
#EX.2   ########
plt.bar(passenger_sex, passenger_sex_value)
plt.bar(passenger_surv, passenger_surv_val)
# Out:
# <BarContainer object of 2 artists>

# %%
# Ex. 3  เเสดงการมีชีวิตรอดเเละไม่รอดจำเเนกตามเพศ
ax1 = plt.subplot2grid((1,2), (0,0))
ax2 = plt.subplot2grid((1,2), (0,1))
relative_male = np.array([float(item) for item in titanics[1:,1]=='Male'])
relative_female = np.array([float(item) for item in titanics[1:,1]=='Female'])
relative_male_sum = sum(relative_male)
relative_female_sum = sum(relative_female)

survive = titanics[1:,-1]
male_not_survived = sum(relative_male[survive=='No'])
male_survived= sum(relative_male[survive=='Yes'])
male_wtf = [male_not_survived,male_survived]
female_not_survived = sum(relative_female[survive=='No'])
female_survived= sum(relative_female[survive=='Yes'])
female_wtf = [female_not_survived,female_survived]
print("'Survive and not Survive sort by Sex' ")
print("Color Blue = 'Survive' And Red = 'not Survive' ")
ax1.bar(passenger_sex,[female_survived,male_survived])
ax2.bar(passenger_sex,[female_not_survived,male_not_survived], color=['red'])
# Out:
# 'Survive and not Survive sort by Sex'
# Color Blue = 'Survive' And Red = 'not Survive'
# <BarContainer object of 2 artists>

# %%
#EX4
#ข้อมูลจาก https://news.thaipbs.or.th/content/303445
CM_covid = folium.Map(location = [18.791444326185538, 98.9929939024392], zoom_start =10)
folium.Circle(radius=700, location=[19.033268492749364, 98.82182747675692], color='red').add_to(CM_covid)
folium.Circle(radius=11050, location=[18.83905750732829, 98.97247631733117], color='red').add_to(CM_covid)
folium.Circle(radius=600, location=[18.873596436748773, 99.1328313143343], color='red').add_to(CM_covid)
folium.Circle(radius=1040, location=[18.753829689870724, 99.16764937080168], color='red').add_to(CM_covid)
folium.Circle(radius=2160, location=[18.844798248891216, 99.04509881954705], color='red').add_to(CM_covid)
folium.Circle(radius=850, location=[18.696862412748093, 98.91982803643313], color='red').add_to(CM_covid)
folium.Circle(radius=1000, location=[18.697947834309623, 99.01697465904643], color='red').add_to(CM_covid)
folium.Circle(radius=400, location=[18.632108190023374, 98.89672653145978], color='orange').add_to(CM_covid)
folium.Circle(radius=270, location=[19.21566625665331, 98.87858449588475], color='orange').add_to(CM_covid)
CM_covid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import matplotlib.pyplot as plt
data = [2,4,6,5,7,6,8,5,4,6,8,10]

plt.plot(data)                
plt.show()

# %%
plt.plot(data, color='green')   
plt.show()

# %%
#EX1 ## 2วิธี
#EX1.1
import numpy as np
from scipy.interpolate import make_interp_spline
import matplotlib.pyplot as plt
 

x = np.array([0,1.6,3,4.9,7.9,9,10])
y = np.array([0,1,0,-1,1,0.25,-0.5])
 
X_Y_Spline = make_interp_spline(x, y)

X_ = np.linspace(x.min(), x.max(), 500)
Y_ = X_Y_Spline(X_)

plt.plot(X_, Y_)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
#EX1.2
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(0, 3.5 * np.pi, 100)
Ya = np.sin(X)


plt.plot(X, Ya)

plt.show()

# %%
import seaborn as sns
sns.set()
data = [2,4,6,5,7,6,8,5,4,6,8,10]
months = range(1, len(data)+1)    # begin X (months) at 1 instead of 0
plt.plot(months, data)             # pass both X and Y list values to the plot
plt.title('Stock prices in 2017') # use the `title()` function and pass a string
plt.xlabel('Months')              # use the `xlabel()` function and pass a string
plt.ylabel('Price in USD')        # use the `ylabel()` function and pass a string
plt.axis([0,13,0,11])             # specify viewport with values [xmin,xmax,ymin,ymax]
#plt.grid()                       # use the `grid()` function to turn on the axes grid
plt.show()

# %%
import numpy as np
titanics = np.genfromtxt('../input/testtitanic123/titanic.txt',delimiter='\t',missing_values = None,dtype=str)

# %%
titanics[0,:]
# Out:
# array(['Passenger Class', 'Name', 'Sex', 'Age',
#        'No of Siblings or Spouses on Board',
#        'No of Parents or Children on Board', 'Ticket Number',
#        'Passenger Fare', 'Cabin', 'Port of Embarkation', 'Life Boat',
#        'Survived'], dtype='<U84')

# %%
titanics = np.delete(titanics,[1,6,7,8,9,10],1)

# %%
titanics[0,:]
# Out:
# array(['Passenger Class', 'Sex', 'Age',
#        'No of Siblings or Spouses on Board',
#        'No of Parents or Children on Board', 'Survived'], dtype='<U84')

# %%
rows, cols = np.where(titanics == None)
rows
# Out:
# array([], dtype=int64)

# %%
rows, cols = np.where(titanics == '')
np.unique(rows)
# Out:
# array([  16,   38,   41,   47,   60,   70,   71,   75,   81,  107,  108,
#         109,  119,  122,  126,  135,  148,  153,  158,  167,  177,  180,
#         185,  197,  205,  220,  224,  236,  238,  242,  255,  257,  270,
#         278,  284,  294,  298,  319,  321,  364,  383,  385,  411,  470,
#         474,  478,  484,  492,  496,  525,  529,  532,  582,  596,  598,
#         673,  681,  682,  683,  706,  707,  757,  758,  768,  769,  776,
#         790,  796,  799,  801,  802,  803,  805,  806,  809,  813,  814,
#         816,  817,  820,  836,  843,  844,  853,  855,  857,  859,  866,
#         872,  873,  875,  877,  880,  883,  887,  888,  901,  902,  903,
#         904,  919,  921,  922,  923,  924,  927,  928,  929,  930,  931,
#         932,  941,  943,  945,  946,  947,  949,  955,  956,  957,  958,
#         959,  962,  963,  972,  974,  977,  983,  984,  985,  988,  989,
#         990,  992,  994,  995,  998,  999, 1000, 1001, 1002, 1003, 1004,
# ...

# %%
rows, cols = np.where(titanics == '')
print(str(len(np.unique(rows)))+" "+str(len(np.unique(cols))))
# Out:
# 263 1

# %%
titanics = np.delete(titanics,2,1)
titanics[0,:]
# Out:
# array(['Passenger Class', 'Sex', 'No of Siblings or Spouses on Board',
#        'No of Parents or Children on Board', 'Survived'], dtype='<U84')

# %%
passenger_class = np.unique(titanics[1:,0])
passenger_class
# Out:
# array(['First', 'Second', 'Third'], dtype='<U84')

# %%
passenger_class_value = [sum(titanics[:,0]==passenger_class[0]),sum(titanics[:,0]==passenger_class[1]),sum(titanics[:,0]==passenger_class[2]) ]
passenger_class_value
# Out:
# [323, 277, 709]

# %%
plt.bar(passenger_class, passenger_class_value)
# Out:
# <BarContainer object of 3 artists>

# %%
titanics
# Out:
# array([['Passenger Class', 'Sex', 'No of Siblings or Spouses on Board',
#         'No of Parents or Children on Board', 'Survived'],
#        ['First', 'Female', '0', '0', 'Yes'],
#        ['First', 'Male', '1', '2', 'Yes'],
#        ...,
#        ['Third', 'Male', '0', '0', 'No'],
#        ['Third', 'Male', '0', '0', 'No'],
#        ['Third', 'Male', '0', '0', 'No']], dtype='<U84')

# %%
passenger_sex = np.unique(titanics[1:4,1])
passenger_sex
# Out:
# array(['Female', 'Male'], dtype='<U84')

# %%
titanics[:,1]
# Out:
# array(['Sex', 'Female', 'Male', ..., 'Male', 'Male', 'Male'], dtype='<U84')

# %%
passenger_sex_value = [sum(titanics[:,1]==passenger_sex[0]),sum(titanics[:,1]==passenger_sex[1]) ]
passenger_sex_value
# Out:
# [466, 843]

# %%
passenger_surv = np.unique(titanics[1:,4])
passenger_surv
# Out:
# array(['No', 'Yes'], dtype='<U84')

# %%
titanics[:,1]
# Out:
# array(['Sex', 'Female', 'Male', ..., 'Male', 'Male', 'Male'], dtype='<U84')

# %%
passenger_surv_val = [sum(titanics[:,4]==passenger_surv[0]),sum(titanics[:,4]==passenger_surv[1]) ]
passenger_surv_val
# Out:
# [809, 500]

# %%
#EX.2   ########
plt.bar(passenger_sex, passenger_sex_value)
plt.bar(passenger_surv, passenger_surv_val)
# Out:
# <BarContainer object of 2 artists>

# %%
titanics[1:,4]
# Out:
# array(['Yes', 'Yes', 'No', ..., 'No', 'No', 'No'], dtype='<U84')

# %%
passenger_sex_value = [sum(titanics[:,1]==passenger_sex[0]),sum(titanics[:,1]==passenger_sex[1]) ]
passenger_sex_value
# Out:
# [466, 843]

# %%
ax1 = plt.subplot2grid((1,2), (0,0))
ax2 = plt.subplot2grid((1,2), (0,1))
relative_male = np.array([float(item) for item in titanics[1:,1]=='Male'])
relative_female = np.array([float(item) for item in titanics[1:,1]=='Female'])
relative_male_sum = sum(relative_male)
relative_female_sum = sum(relative_female)

survive = titanics[1:,-1]
male_not_survived = sum(relative_male[survive=='No'])
male_survived= sum(relative_male[survive=='Yes'])
male_wtf = [male_not_survived,male_survived]
female_not_survived = sum(relative_female[survive=='No'])
female_survived= sum(relative_female[survive=='Yes'])
female_wtf = [female_not_survived,female_survived]
print("'Survive and not Survive sort by Sex' ")
print("Color Blue = 'Survive' And Red = 'not Survive' ")
ax1.bar(passenger_sex,[male_survived,female_survived])
ax2.bar(passenger_sex,[male_not_survived,female_not_survived], color=['red'])
# Out:
# 'Survive and not Survive sort by Sex'
# Color Blue = 'Survive' And Red = 'not Survive'
# <BarContainer object of 2 artists>

# %%
relative = np.array([float(item) for item in titanics[1:,2]])
plt.boxplot(relative, labels = ['All'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0984a7a510>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f0984a7ad90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0984a7a150>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0984a845d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0984a84a10>],
#  'means': []}

# %%
relative = np.array([float(item) for item in titanics[1:,2]])
survive = titanics[1:,-1]
plt.boxplot([relative[survive=='No'], relative[survive=='Yes'] ], labels = ['die','survive'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f09860bf650>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f09860bfe90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f09860bf290>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f09860c9690>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f09860c9ad0>,
# ...
#  'means': []}

# %%
titanics[0:,1]
# Out:
# array(['Sex', 'Female', 'Male', ..., 'Male', 'Male', 'Male'], dtype='<U84')

# %%
# Ex. 3 Using Box Plot to analyze, what is the cause of die or survive
relative = np.array([float(item) for item in titanics[1:,3]])
survive = titanics[1:,-1]
plt.title("' Relation of No of Parents or Children on Board to Die and Survive ' ")

plt.boxplot([relative[survive=='No'], relative[survive=='Yes'] ], labels = ['die','survive'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0986061650>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f0986061ed0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0986061250>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f0985feb7d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0985febc10>,
# ...
#  'means': []}

# %%
relative_male = np.array([float(item) for item in titanics[1:,1]=='Male'])
relative_female = np.array([float(item) for item in titanics[1:,1]=='Female'])


survive = titanics[1:,-1]

plt.boxplot([relative_male[survive=='No'], relative_female[survive=='No'],relative_male[survive=='Yes'],relative_female[survive=='Yes'] ], labels = ['Male die','Female die','Male Survive','Female survive'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0985f784d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f0985f78d50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0985f78110>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f0985f83650>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0985f83a90>,
# ...
#  'means': []}

# %%
import numpy as np
relative_male = np.array([float(item) for item in titanics[1:,1]=='Male'])
survive = titanics[1:,-1]
plt.boxplot([relative_male], labels = ['Male '])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0985ec8a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f0985ed1290>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0985ec8790>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0985ed1b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0985ed1f90>],
#  'means': []}

# %%
relative_male = np.array([float(item) for item in titanics[1:,1]=='Male'])
relative_male
# Out:
# array([0., 1., 0., ..., 1., 1., 1.])

# %%
import folium
world_map = folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
cmu_map = folium.Map(location = [18.7971238,98.9537993], zoom_start =15)
cmu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
cmu_map = folium.Map(location = [18.7971238,98.9537993], zoom_start =15, tiles='Stamen Terrain')
cmu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
folium.TileLayer('Stamen Watercolor').add_to(cmu_map)
cmu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# !pip install geocoder
import geocoder
# Out:
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
location = 'น้ำตกแม่สา'
loc = geocoder.osm(location)
loc.json
# Out:
# {'accuracy': 0.75,
#  'address': 'น้ำตกแม่สา, แม่แรม, จังหวัดเชียงใหม่, 50180, ประเทศไทย',
#  'bbox': {'northeast': [18.9066127, 98.8967386],
#   'southwest': [18.9065127, 98.8966386]},
#  'confidence': 10,
#  'country': 'ประเทศไทย',
#  'country_code': 'th',
#  'importance': 0.75,
#  'lat': 18.9065627,
#  'lng': 98.8966886,
#  'ok': True,
#  'osm_id': 1638690882,
#  'osm_type': 'node',
#  'place_id': 16442596,
#  'place_rank': 20,
#  'postal': '50180',
#  'quality': 'waterfall',
#  'raw': {'place_id': 16442596,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 1638690882,
#   'boundingbox': ['18.9065127', '18.9066127', '98.8966386', '98.8967386'],
#   'lat': '18.9065627',
#   'lon': '98.8966886',
#   'display_name': 'น้ำตกแม่สา, แม่แรม, จังหวัดเชียงใหม่, 50180, ประเทศไทย',
#   'place_rank': 20,
#   'category': 'waterway',
#   'type': 'waterfall',
#   'importance': 0.75,
# ...

# %%
from folium import Map, Marker, GeoJson, LayerControl
latlng = [loc.lat, loc.lng]
maesa_map = Map(location=latlng, zoom_start=15)
maesa_map.add_child(Marker(location=latlng, popup="This is waterfall", icon = folium.Icon(color = 'blue', icon = 'home'), tooltip = "Click for more"))
maesa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#EX4
#ข้อมูลจาก https://news.thaipbs.or.th/content/303445
CM_covid = folium.Map(location = [18.791444326185538, 98.9929939024392], zoom_start =10)
folium.Circle(radius=700, location=[19.033268492749364, 98.82182747675692], color='red').add_to(CM_covid)
folium.Circle(radius=11050, location=[18.83905750732829, 98.97247631733117], color='red').add_to(CM_covid)
folium.Circle(radius=600, location=[18.873596436748773, 99.1328313143343], color='red').add_to(CM_covid)
folium.Circle(radius=1040, location=[18.753829689870724, 99.16764937080168], color='red').add_to(CM_covid)
folium.Circle(radius=2160, location=[18.844798248891216, 99.04509881954705], color='red').add_to(CM_covid)
folium.Circle(radius=850, location=[18.696862412748093, 98.91982803643313], color='red').add_to(CM_covid)
folium.Circle(radius=1000, location=[18.697947834309623, 99.01697465904643], color='red').add_to(CM_covid)
folium.Circle(radius=400, location=[18.632108190023374, 98.89672653145978], color='orange').add_to(CM_covid)
folium.Circle(radius=270, location=[19.21566625665331, 98.87858449588475], color='orange').add_to(CM_covid)
CM_covid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
titanics_2 = np.genfromtxt('../input/testtitanic123/titanic.txt',delimiter='\t',missing_values = None,dtype=str)
titanics_2[0,0:]
# Out:
# array(['Passenger Class', 'Name', 'Sex', 'Age',
#        'No of Siblings or Spouses on Board',
#        'No of Parents or Children on Board', 'Ticket Number',
#        'Passenger Fare', 'Cabin', 'Port of Embarkation', 'Life Boat',
#        'Survived'], dtype='<U84')
