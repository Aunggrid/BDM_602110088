# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np 
import pandas as pd

# %%
import glob
filename = glob.glob("../input/bdm-2021-face/*.*")
filename[0]
# Out:
# '../input/bdm-2021-face/622110140_4_0.jpg'

# %%
filename[0].split("_")
# Out:
# ['../input/bdm-2021-face/622110140', '4', '0.jpg']

# %%
filename[0].split("_")[-1].split(".")[0]
# Out:
# '0'

# %%
label = np.array([float(item.split("_")[-1].split(".")[0]) for item in filename])

# %%
# !mkdir train
# !mkdir train/male
# !mkdir train/female

# %%
import shutil
for i in range(len(label)):
    if label[i] == 0:
        shutil.copy(filename[i], '/kaggle/working/train/male')
    else:
        shutil.copy(filename[i], '/kaggle/working/train/female')

# %%
# !mkdir test
# !mkdir test/male
# !mkdir test/female

# %%
import glob
filemale = np.array(glob.glob("./train/male/*.*"))
filefemale = np.array(glob.glob("./train/female/*.*"))

# %%
midx = np.random.randint(len(filemale), size = 4)
fidx = np.random.randint(len(filefemale), size = 2)

# %%
for i in fidx:
    shutil.move(filefemale[i],'./test/female/')
for i in midx:
    shutil.move(filemale[i],'./test/male/')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_generator = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        #rescale = 1.0/255.0,   # Intensity Normalized
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False,   # randomly flip images
        validation_split=0.2)
# Out:
# 2021-09-20 22:18:36.345676: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2021-09-20 22:18:36.345795: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
train_dir = './train'

batch_size = 5 # ส่งไปเทรนทีละ5 เพราะมีรูป ผญ 15 คน
img_height = 100
img_width  = 100
train_generator = data_generator.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training') # set as training data

validation_generator = data_generator.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation') # set as validation data
# Out:
# Found 63 images belonging to 2 classes.
# Found 15 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'female': 0, 'male': 1}

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
# preparing the layers in the Convolutional Deep Neural Network
def create_model():
    tf.random.set_seed(0)
    tf.compat.v1.reset_default_graph() # Clear Model
    model = Sequential()
    model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', input_shape = train_generator.image_shape)) 
    # Conv2Dตัวสกัดfilters
    model.add(MaxPooling2D(pool_size = (2, 2)))
    #ย่อภาพลงมา
    
    model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
   
    
    model.add(Conv2D(filters = 8, kernel_size = (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(rate = 0.15))
    
    model.add(Flatten())
    #ตบถาพให้แบนเป็น2มิติลงมา
    
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 32, activation = 'relu'))
    model.add(Dense(units = 16, activation = 'relu'))
    model.add(Dropout(rate = 0.1))
    
    model.add(Dense(units = 1, activation = 'sigmoid'))
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
model = create_model()
# Out:
# 2021-09-20 22:19:55.223548: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-20 22:19:55.228957: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2021-09-20 22:19:55.229000: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-09-20 22:19:55.229033: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (a2557bec85bc): /proc/driver/nvidia/version does not exist
# 2021-09-20 22:19:55.231907: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-20 22:19:55.232253: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
fitted_model = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = 99)
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2021-09-20 22:20:05.027274: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-20 22:20:05.032355: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2299995000 Hz
# Epoch 1/99
# 12/12 [==============================] - 7s 562ms/step - loss: 3.5692 - accuracy: 0.4606 - val_loss: 0.8349 - val_accuracy: 0.7333
# Epoch 2/99
# 12/12 [==============================] - 5s 432ms/step - loss: 0.6161 - accuracy: 0.7367 - val_loss: 0.8378 - val_accuracy: 0.7333
# Epoch 3/99
# 12/12 [==============================] - 5s 458ms/step - loss: 0.7780 - accuracy: 0.5234 - val_loss: 0.6657 - val_accuracy: 0.8000
# Epoch 4/99
# 12/12 [==============================] - 5s 437ms/step - loss: 0.6767 - accuracy: 0.7110 - val_loss: 0.7073 - val_accuracy: 0.5333
# Epoch 5/99
# 12/12 [==============================] - 5s 429ms/step - loss: 0.5582 - accuracy: 0.6274 - val_loss: 0.6759 - val_accuracy: 0.6667
# Epoch 6/99
# 12/12 [==============================] - 5s 476ms/step - loss: 0.5501 - accuracy: 0.6826 - val_loss: 0.6548 - val_accuracy: 0.6667
# Epoch 7/99
# 12/12 [==============================] - 5s 444ms/step - loss: 0.5244 - accuracy: 0.7963 - val_loss: 0.5984 - val_accuracy: 0.6000
# Epoch 8/99
# 12/12 [==============================] - 5s 383ms/step - loss: 0.6333 - accuracy: 0.7666 - val_loss: 0.8948 - val_accuracy: 0.6667
# Epoch 9/99
# 12/12 [==============================] - 5s 433ms/step - loss: 0.4281 - accuracy: 0.7095 - val_loss: 0.5151 - val_accuracy: 0.7333
# Epoch 10/99
# 12/12 [==============================] - 5s 429ms/step - loss: 0.5099 - accuracy: 0.6903 - val_loss: 0.5349 - val_accuracy: 0.7333
# Epoch 11/99
# 12/12 [==============================] - 5s 464ms/step - loss: 0.3401 - accuracy: 0.8193 - val_loss: 0.4915 - val_accuracy: 0.7333
# Epoch 12/99
# 12/12 [==============================] - 5s 447ms/step - loss: 0.4551 - accuracy: 0.7738 - val_loss: 0.4323 - val_accuracy: 0.8000
# Epoch 13/99
# 12/12 [==============================] - 5s 481ms/step - loss: 0.3884 - accuracy: 0.8385 - val_loss: 0.7462 - val_accuracy: 0.6000
# Epoch 14/99
# 12/12 [==============================] - 5s 429ms/step - loss: 0.4303 - accuracy: 0.7075 - val_loss: 0.5091 - val_accuracy: 0.8667
# Epoch 15/99
# 12/12 [==============================] - 5s 477ms/step - loss: 0.5355 - accuracy: 0.7113 - val_loss: 0.5221 - val_accuracy: 0.7333
# Epoch 16/99
# 12/12 [==============================] - 5s 444ms/step - loss: 0.6164 - accuracy: 0.7104 - val_loss: 0.5632 - val_accuracy: 0.8000
# Epoch 17/99
# 12/12 [==============================] - 5s 409ms/step - loss: 0.4703 - accuracy: 0.7074 - val_loss: 0.5019 - val_accuracy: 0.7333
# Epoch 18/99
# 12/12 [==============================] - 5s 415ms/step - loss: 0.4201 - accuracy: 0.8168 - val_loss: 0.6401 - val_accuracy: 0.6667
# Epoch 19/99
# 12/12 [==============================] - 5s 460ms/step - loss: 0.3478 - accuracy: 0.9240 - val_loss: 0.5612 - val_accuracy: 0.8667
# Epoch 20/99
# 12/12 [==============================] - 5s 465ms/step - loss: 0.3105 - accuracy: 0.7641 - val_loss: 0.5405 - val_accuracy: 0.8000
# Epoch 21/99
# 12/12 [==============================] - 5s 414ms/step - loss: 0.3864 - accuracy: 0.8601 - val_loss: 0.5332 - val_accuracy: 0.8667
# Epoch 22/99
# 12/12 [==============================] - 5s 461ms/step - loss: 0.3285 - accuracy: 0.8301 - val_loss: 0.4460 - val_accuracy: 0.7333
# Epoch 23/99
# 12/12 [==============================] - 5s 433ms/step - loss: 0.4328 - accuracy: 0.7645 - val_loss: 0.4757 - val_accuracy: 0.8000
# Epoch 24/99
# 12/12 [==============================] - 5s 440ms/step - loss: 0.4309 - accuracy: 0.7139 - val_loss: 0.4872 - val_accuracy: 0.6000
# Epoch 25/99
# 12/12 [==============================] - 5s 401ms/step - loss: 0.4231 - accuracy: 0.7610 - val_loss: 0.4334 - val_accuracy: 0.8667
# Epoch 26/99
# 12/12 [==============================] - 5s 414ms/step - loss: 0.3000 - accuracy: 0.8418 - val_loss: 0.2760 - val_accuracy: 0.9333
# Epoch 27/99
# 12/12 [==============================] - 5s 477ms/step - loss: 0.2703 - accuracy: 0.8526 - val_loss: 0.6808 - val_accuracy: 0.7333
# Epoch 28/99
# 12/12 [==============================] - 5s 431ms/step - loss: 0.3125 - accuracy: 0.8617 - val_loss: 0.3938 - val_accuracy: 0.8667
# Epoch 29/99
# 12/12 [==============================] - 5s 463ms/step - loss: 0.3747 - accuracy: 0.7796 - val_loss: 0.5727 - val_accuracy: 0.7333
# Epoch 30/99
# 12/12 [==============================] - 5s 392ms/step - loss: 0.4048 - accuracy: 0.7562 - val_loss: 0.5878 - val_accuracy: 0.7333
# Epoch 31/99
# 12/12 [==============================] - 5s 449ms/step - loss: 0.2649 - accuracy: 0.8629 - val_loss: 0.6652 - val_accuracy: 0.7333
# Epoch 32/99
# 12/12 [==============================] - 5s 455ms/step - loss: 0.3254 - accuracy: 0.8610 - val_loss: 0.6059 - val_accuracy: 0.8000
# Epoch 33/99
# 12/12 [==============================] - 5s 425ms/step - loss: 0.4716 - accuracy: 0.8290 - val_loss: 0.8070 - val_accuracy: 0.7333
# Epoch 34/99
# 12/12 [==============================] - 5s 410ms/step - loss: 0.2385 - accuracy: 0.8337 - val_loss: 0.9221 - val_accuracy: 0.6000
# Epoch 35/99
# 12/12 [==============================] - 5s 418ms/step - loss: 0.2677 - accuracy: 0.9208 - val_loss: 0.2842 - val_accuracy: 0.8667
# Epoch 36/99
# 12/12 [==============================] - 5s 400ms/step - loss: 0.5693 - accuracy: 0.7873 - val_loss: 0.7868 - val_accuracy: 0.7333
# Epoch 37/99
# 12/12 [==============================] - 5s 430ms/step - loss: 0.2794 - accuracy: 0.8640 - val_loss: 0.4128 - val_accuracy: 0.7333
# Epoch 38/99
# 12/12 [==============================] - 5s 432ms/step - loss: 0.3898 - accuracy: 0.8406 - val_loss: 0.2903 - val_accuracy: 0.8667
# Epoch 39/99
# 12/12 [==============================] - 5s 462ms/step - loss: 0.2438 - accuracy: 0.9255 - val_loss: 0.7317 - val_accuracy: 0.7333
# Epoch 40/99
# 12/12 [==============================] - 5s 434ms/step - loss: 0.3059 - accuracy: 0.8251 - val_loss: 0.4346 - val_accuracy: 0.7333
# Epoch 41/99
# 12/12 [==============================] - 5s 398ms/step - loss: 0.2619 - accuracy: 0.8633 - val_loss: 0.5142 - val_accuracy: 0.8000
# Epoch 42/99
# 12/12 [==============================] - 5s 464ms/step - loss: 0.3200 - accuracy: 0.7797 - val_loss: 0.2817 - val_accuracy: 0.9333
# Epoch 43/99
# 12/12 [==============================] - 5s 435ms/step - loss: 0.2143 - accuracy: 0.8568 - val_loss: 0.3424 - val_accuracy: 0.8667
# Epoch 44/99
# 12/12 [==============================] - 5s 443ms/step - loss: 0.2153 - accuracy: 0.9117 - val_loss: 0.3730 - val_accuracy: 0.8667
# Epoch 45/99
# 12/12 [==============================] - 5s 469ms/step - loss: 0.1494 - accuracy: 0.9579 - val_loss: 0.6903 - val_accuracy: 0.7333
# Epoch 46/99
# 12/12 [==============================] - 5s 439ms/step - loss: 0.2884 - accuracy: 0.8500 - val_loss: 0.3867 - val_accuracy: 0.8000
# Epoch 47/99
# 12/12 [==============================] - 5s 413ms/step - loss: 0.3741 - accuracy: 0.8869 - val_loss: 0.2822 - val_accuracy: 0.8667
# Epoch 48/99
# 12/12 [==============================] - 5s 435ms/step - loss: 0.2430 - accuracy: 0.8809 - val_loss: 0.2572 - val_accuracy: 0.9333
# Epoch 49/99
# 12/12 [==============================] - 5s 372ms/step - loss: 0.1654 - accuracy: 0.9296 - val_loss: 0.4481 - val_accuracy: 0.7333
# Epoch 50/99
# 12/12 [==============================] - 5s 413ms/step - loss: 0.2143 - accuracy: 0.8574 - val_loss: 0.5518 - val_accuracy: 0.8667
# Epoch 51/99
# 12/12 [==============================] - 5s 444ms/step - loss: 0.3130 - accuracy: 0.9262 - val_loss: 0.7620 - val_accuracy: 0.8000
# Epoch 52/99
# 12/12 [==============================] - 5s 430ms/step - loss: 0.2289 - accuracy: 0.8926 - val_loss: 0.5722 - val_accuracy: 0.7333
# Epoch 53/99
# 12/12 [==============================] - 5s 473ms/step - loss: 0.1439 - accuracy: 0.9646 - val_loss: 0.5126 - val_accuracy: 0.8667
# Epoch 54/99
# 12/12 [==============================] - 5s 428ms/step - loss: 0.1720 - accuracy: 0.8911 - val_loss: 0.4217 - val_accuracy: 0.7333
# Epoch 55/99
# 12/12 [==============================] - 5s 476ms/step - loss: 0.4200 - accuracy: 0.8991 - val_loss: 0.6578 - val_accuracy: 0.6667
# Epoch 56/99
# 12/12 [==============================] - 5s 484ms/step - loss: 0.1708 - accuracy: 0.9429 - val_loss: 0.4391 - val_accuracy: 0.8000
# Epoch 57/99
# 12/12 [==============================] - 5s 433ms/step - loss: 0.1194 - accuracy: 0.9340 - val_loss: 0.7835 - val_accuracy: 0.6667
# Epoch 58/99
# 12/12 [==============================] - 4s 388ms/step - loss: 0.0758 - accuracy: 0.9827 - val_loss: 0.9417 - val_accuracy: 0.6000
# Epoch 59/99
# 12/12 [==============================] - 5s 411ms/step - loss: 0.1898 - accuracy: 0.8817 - val_loss: 0.7568 - val_accuracy: 0.6000
# Epoch 60/99
# 12/12 [==============================] - 5s 464ms/step - loss: 0.1305 - accuracy: 0.9464 - val_loss: 1.4948 - val_accuracy: 0.8000
# Epoch 61/99
# 12/12 [==============================] - 5s 348ms/step - loss: 0.1724 - accuracy: 0.9787 - val_loss: 0.6861 - val_accuracy: 0.5333
# Epoch 62/99
# 12/12 [==============================] - 5s 442ms/step - loss: 0.0952 - accuracy: 0.9809 - val_loss: 2.1743 - val_accuracy: 0.6000
# Epoch 63/99
# 12/12 [==============================] - 5s 466ms/step - loss: 0.1337 - accuracy: 0.9361 - val_loss: 0.7891 - val_accuracy: 0.6000
# Epoch 64/99
# 12/12 [==============================] - 5s 435ms/step - loss: 0.0914 - accuracy: 0.9338 - val_loss: 1.1415 - val_accuracy: 0.8667
# Epoch 65/99
# 12/12 [==============================] - 5s 372ms/step - loss: 0.4066 - accuracy: 0.9195 - val_loss: 0.9484 - val_accuracy: 0.6667
# Epoch 66/99
# 12/12 [==============================] - 5s 431ms/step - loss: 0.1053 - accuracy: 0.9745 - val_loss: 0.2936 - val_accuracy: 0.8667
# Epoch 67/99
# 12/12 [==============================] - 5s 461ms/step - loss: 0.1674 - accuracy: 0.9551 - val_loss: 0.3354 - val_accuracy: 0.9333
# Epoch 68/99
# 12/12 [==============================] - 5s 428ms/step - loss: 0.2585 - accuracy: 0.9258 - val_loss: 0.1596 - val_accuracy: 0.8667
# Epoch 69/99
# 12/12 [==============================] - 5s 427ms/step - loss: 0.3194 - accuracy: 0.9286 - val_loss: 0.7297 - val_accuracy: 0.8000
# Epoch 70/99
# 12/12 [==============================] - 5s 442ms/step - loss: 0.2206 - accuracy: 0.9390 - val_loss: 0.7692 - val_accuracy: 0.5333
# Epoch 71/99
# 12/12 [==============================] - 4s 388ms/step - loss: 0.2869 - accuracy: 0.9495 - val_loss: 0.7415 - val_accuracy: 0.8000
# Epoch 72/99
# 12/12 [==============================] - 5s 463ms/step - loss: 0.2644 - accuracy: 0.8464 - val_loss: 0.5842 - val_accuracy: 0.6667
# Epoch 73/99
# 12/12 [==============================] - 5s 429ms/step - loss: 0.2210 - accuracy: 0.9230 - val_loss: 1.2298 - val_accuracy: 0.6667
# Epoch 74/99
# 12/12 [==============================] - 5s 431ms/step - loss: 0.1630 - accuracy: 0.9256 - val_loss: 0.4959 - val_accuracy: 0.7333
# Epoch 75/99
# 12/12 [==============================] - 5s 411ms/step - loss: 0.2869 - accuracy: 0.8554 - val_loss: 0.6318 - val_accuracy: 0.6667
# Epoch 76/99
# 12/12 [==============================] - 5s 398ms/step - loss: 0.2612 - accuracy: 0.8901 - val_loss: 0.9989 - val_accuracy: 0.7333
# Epoch 77/99
# 12/12 [==============================] - 5s 456ms/step - loss: 0.0766 - accuracy: 0.9658 - val_loss: 0.4398 - val_accuracy: 0.8000
# Epoch 78/99
# 12/12 [==============================] - 5s 434ms/step - loss: 0.2636 - accuracy: 0.8791 - val_loss: 0.7053 - val_accuracy: 0.5333
# Epoch 79/99
# 12/12 [==============================] - 5s 463ms/step - loss: 0.1818 - accuracy: 0.8861 - val_loss: 0.9518 - val_accuracy: 0.5333
# Epoch 80/99
# 12/12 [==============================] - 5s 431ms/step - loss: 0.1807 - accuracy: 0.9458 - val_loss: 0.8136 - val_accuracy: 0.5333
# Epoch 81/99
# 12/12 [==============================] - 5s 437ms/step - loss: 0.1610 - accuracy: 0.9657 - val_loss: 0.7894 - val_accuracy: 0.6000
# Epoch 82/99
# 12/12 [==============================] - 5s 409ms/step - loss: 0.0477 - accuracy: 0.9739 - val_loss: 0.1760 - val_accuracy: 0.8667
# Epoch 83/99
# 12/12 [==============================] - 5s 468ms/step - loss: 0.0775 - accuracy: 0.9224 - val_loss: 2.2918 - val_accuracy: 0.6667
# Epoch 84/99
# 12/12 [==============================] - 5s 468ms/step - loss: 0.1653 - accuracy: 0.8849 - val_loss: 1.4095 - val_accuracy: 0.5333
# Epoch 85/99
# 12/12 [==============================] - 5s 419ms/step - loss: 0.2534 - accuracy: 0.9394 - val_loss: 0.5653 - val_accuracy: 0.7333
# Epoch 86/99
# 12/12 [==============================] - 5s 455ms/step - loss: 0.1351 - accuracy: 0.9587 - val_loss: 1.1790 - val_accuracy: 0.6667
# Epoch 87/99
# 12/12 [==============================] - 5s 441ms/step - loss: 0.1542 - accuracy: 0.9854 - val_loss: 1.4074 - val_accuracy: 0.6000
# Epoch 88/99
# 12/12 [==============================] - 5s 411ms/step - loss: 0.1332 - accuracy: 0.9432 - val_loss: 1.5584 - val_accuracy: 0.5333
# Epoch 89/99
# 12/12 [==============================] - 4s 358ms/step - loss: 0.1822 - accuracy: 0.9299 - val_loss: 0.6106 - val_accuracy: 0.6667
# Epoch 90/99
# 12/12 [==============================] - 5s 408ms/step - loss: 0.2447 - accuracy: 0.8943 - val_loss: 0.3255 - val_accuracy: 0.9333
# Epoch 91/99
# 12/12 [==============================] - 5s 421ms/step - loss: 0.1709 - accuracy: 0.9207 - val_loss: 1.4620 - val_accuracy: 0.6667
# Epoch 92/99
# 12/12 [==============================] - 5s 430ms/step - loss: 0.3987 - accuracy: 0.9324 - val_loss: 0.4365 - val_accuracy: 0.7333
# Epoch 93/99
# 12/12 [==============================] - 5s 433ms/step - loss: 0.0815 - accuracy: 0.9637 - val_loss: 0.9454 - val_accuracy: 0.8000
# Epoch 94/99
# 12/12 [==============================] - 5s 413ms/step - loss: 0.0467 - accuracy: 0.9826 - val_loss: 0.8629 - val_accuracy: 0.6000
# Epoch 95/99
# 12/12 [==============================] - 5s 468ms/step - loss: 0.2255 - accuracy: 0.8971 - val_loss: 0.9527 - val_accuracy: 0.6667
# Epoch 96/99
# 12/12 [==============================] - 5s 433ms/step - loss: 0.1832 - accuracy: 0.9430 - val_loss: 1.6445 - val_accuracy: 0.6000
# Epoch 97/99
# 12/12 [==============================] - 5s 461ms/step - loss: 0.2173 - accuracy: 0.9470 - val_loss: 0.3074 - val_accuracy: 0.8667
# Epoch 98/99
# 12/12 [==============================] - 5s 425ms/step - loss: 0.0637 - accuracy: 0.9833 - val_loss: 0.2520 - val_accuracy: 0.8000
# Epoch 99/99
# 12/12 [==============================] - 5s 464ms/step - loss: 0.2980 - accuracy: 0.8738 - val_loss: 0.7017 - val_accuracy: 0.8000

# %%
import matplotlib.pyplot as plt
# plotting accuracy and validation accuracy
accuracy = fitted_model.history['accuracy']
val_accuracy = fitted_model.history['val_accuracy']
plt.plot(range(len(accuracy)), accuracy, 'b-', label = 'accuracy')
plt.plot(range(len(val_accuracy)), val_accuracy, 'r-', label = 'val_accuracy')
plt.legend()

# %%
import glob
filefemale = glob.glob("./test/female/*.*")
filemale = glob.glob("./test/male/*.*")

# %%
from tensorflow.keras.preprocessing import image
# testing the model
plabel = []
for filename in filefemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==0)/len(plabel)
# Out:
# 1.0

# %%
plabel = []
for filename in filemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==1)/len(plabel)
# Out:
# 1.0
