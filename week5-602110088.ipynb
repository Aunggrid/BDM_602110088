# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/clinic/ultima_all_clean.csv
# /kaggle/input/testtitanic123/titanic.txt

# %%
#EX COVID
# !pip install geocoder
import geocoder
import folium
#ข้อมูลจาก https://news.thaipbs.or.th/content/303445
CM_covid = folium.Map(location = [18.791444326185538, 98.9929939024392], zoom_start =10)
folium.Circle(radius=700, location=[19.033268492749364, 98.82182747675692], color='red').add_to(CM_covid)
folium.Circle(radius=11050, location=[18.83905750732829, 98.97247631733117], color='red').add_to(CM_covid)
folium.Circle(radius=600, location=[18.873596436748773, 99.1328313143343], color='red').add_to(CM_covid)
folium.Circle(radius=1040, location=[18.753829689870724, 99.16764937080168], color='red').add_to(CM_covid)
folium.Circle(radius=2160, location=[18.844798248891216, 99.04509881954705], color='red').add_to(CM_covid)
folium.Circle(radius=850, location=[18.696862412748093, 98.91982803643313], color='red').add_to(CM_covid)
folium.Circle(radius=1000, location=[18.697947834309623, 99.01697465904643], color='red').add_to(CM_covid)
folium.Circle(radius=400, location=[18.632108190023374, 98.89672653145978], color='orange').add_to(CM_covid)
folium.Circle(radius=270, location=[19.21566625665331, 98.87858449588475], color='orange').add_to(CM_covid)
CM_covid
# Out:
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../input/testtitanic123/titanic.txt', sep='\t', header = 0)
df
# Out:
#      Passenger Class                                             Name     Sex  \
# 0              First                    Allen, Miss. Elisabeth Walton  Female
# 1              First                   Allison, Master. Hudson Trevor    Male
# 2              First                     Allison, Miss. Helen Loraine  Female
# 3              First             Allison, Mr. Hudson Joshua Creighton    Male
# 4              First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# ...              ...                                              ...     ...
# 1304           Third                             Zabour, Miss. Hileni  Female
# 1305           Third                            Zabour, Miss. Thamine  Female
# 1306           Third                        Zakarian, Mr. Mapriededer    Male
# 1307           Third                              Zakarian, Mr. Ortin    Male
# 1308           Third                               Zimmerman, Mr. Leo    Male
#
# ...

# %%
df.columns
# Out:
# Index(['Passenger Class', 'Name', 'Sex', 'Age',
#        'No of Siblings or Spouses on Board',
#        'No of Parents or Children on Board', 'Ticket Number', 'Passenger Fare',
#        'Cabin', 'Port of Embarkation', 'Life Boat', 'Survived'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: Name, Length: 1309, dtype: object

# %%
df.iloc[1,0:5]
# Out:
# Passenger Class                                                First
# Name                                  Allison, Master. Hudson Trevor
# Sex                                                             Male
# Age                                                                1
# No of Siblings or Spouses on Board                                 1
# Name: 1, dtype: object

# %%
df.loc[2,'Passenger Class':'Age']
# Out:
# Passenger Class                           First
# Name               Allison, Miss. Helen Loraine
# Sex                                      Female
# Age                                           2
# Name: 2, dtype: object

# %%
df.dtypes
# Out:
# Passenger Class                        object
# Name                                   object
# Sex                                    object
# Age                                   float64
# No of Siblings or Spouses on Board      int64
# No of Parents or Children on Board      int64
# Ticket Number                          object
# Passenger Fare                        float64
# Cabin                                  object
# Port of Embarkation                    object
# Life Boat                              object
# Survived                               object
# dtype: object

# %%
pd.options.display.float_format = "{:,.4f}".format
df
# Out:
#      Passenger Class                                             Name     Sex  \
# 0              First                    Allen, Miss. Elisabeth Walton  Female
# 1              First                   Allison, Master. Hudson Trevor    Male
# 2              First                     Allison, Miss. Helen Loraine  Female
# 3              First             Allison, Mr. Hudson Joshua Creighton    Male
# 4              First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# ...              ...                                              ...     ...
# 1304           Third                             Zabour, Miss. Hileni  Female
# 1305           Third                            Zabour, Miss. Thamine  Female
# 1306           Third                        Zakarian, Mr. Mapriededer    Male
# 1307           Third                              Zakarian, Mr. Ortin    Male
# 1308           Third                               Zimmerman, Mr. Leo    Male
#
# ...

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].min()
# Out:
# 0.1667

# %%
df[df['Age']==df['Age'].min()]
# Out:
#     Passenger Class                                     Name     Sex    Age  \
# 763           Third  Dean, Miss. Elizabeth Gladys 'Millvina'  Female 0.1667
#
#      No of Siblings or Spouses on Board  No of Parents or Children on Board  \
# 763                                   1                                   2
#
#     Ticket Number  Passenger Fare Cabin Port of Embarkation Life Boat Survived
# 763     C.A. 2315         20.5750   NaN         Southampton        10      Yes

# %%
df['Name'][df['Age']==df['Age'].max()]
# Out:
# 14    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df.shape
# Out:
# (1309, 12)

# %%
df['Sex'].tolist()
# Out:
# ['Female',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Male',
#  'Male',
#  'Female',
#  'Female',
#  'Female',
#  'Male',
#  'Male',
#  'Male',
#  'Female',
#  'Female',
#  'Male',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Female',
#  'Male',
#  'Male',
#  'Female',
#  'Female',
#  'Male',
#  'Male',
#  'Male',
#  'Female',
#  'Female',
#  'Male',
#  'Female',
#  'Female',
#  'Male',
#  'Male',
#  'Male',
#  'Male',
#  'Female',
#  'Female',
#  'Female',
#  'Female',
#  'Male',
#  'Male',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Male',
#  'Male',
#  'Male',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Female',
#  'Female',
#  'Male',
#  'Female',
#  'Male',
#  'Male',
#  'Female',
#  'Female',
#  'Male',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Female',
#  'Male',
#  'Male',
#  'Female',
# ...

# %%
df.values
# Out:
# array([['First', 'Allen, Miss. Elisabeth Walton', 'Female', ...,
#         'Southampton', '2', 'Yes'],
#        ['First', 'Allison, Master. Hudson Trevor', 'Male', ...,
#         'Southampton', '11', 'Yes'],
#        ['First', 'Allison, Miss. Helen Loraine', 'Female', ...,
#         'Southampton', nan, 'No'],
#        ...,
#        ['Third', 'Zakarian, Mr. Mapriededer', 'Male', ..., 'Cherbourg',
#         nan, 'No'],
#        ['Third', 'Zakarian, Mr. Ortin', 'Male', ..., 'Cherbourg', nan,
#         'No'],
#        ['Third', 'Zimmerman, Mr. Leo', 'Male', ..., 'Southampton', nan,
#         'No']], dtype=object)

# %%
df['Label'] = df['Age'] >= 20
df
# Out:
#      Passenger Class                                             Name     Sex  \
# 0              First                    Allen, Miss. Elisabeth Walton  Female
# 1              First                   Allison, Master. Hudson Trevor    Male
# 2              First                     Allison, Miss. Helen Loraine  Female
# 3              First             Allison, Mr. Hudson Joshua Creighton    Male
# 4              First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# ...              ...                                              ...     ...
# 1304           Third                             Zabour, Miss. Hileni  Female
# 1305           Third                            Zabour, Miss. Thamine  Female
# 1306           Third                        Zakarian, Mr. Mapriededer    Male
# 1307           Third                              Zakarian, Mr. Ortin    Male
# 1308           Third                               Zimmerman, Mr. Leo    Male
#
# ...

# %%
df.isnull()
# Out:
#       Passenger Class   Name    Sex    Age  \
# 0               False  False  False  False
# 1               False  False  False  False
# 2               False  False  False  False
# 3               False  False  False  False
# 4               False  False  False  False
# ...               ...    ...    ...    ...
# 1304            False  False  False  False
# 1305            False  False  False   True
# 1306            False  False  False  False
# 1307            False  False  False  False
# 1308            False  False  False  False
#
#       No of Siblings or Spouses on Board  No of Parents or Children on Board  \
# 0                                  False                               False
# 1                                  False                               False
# 2                                  False                               False
# 3                                  False                               False
# ...

# %%
df.isnull().any()
# Out:
# Passenger Class                       False
# Name                                  False
# Sex                                   False
# Age                                    True
# No of Siblings or Spouses on Board    False
# No of Parents or Children on Board    False
# Ticket Number                         False
# Passenger Fare                         True
# Cabin                                  True
# Port of Embarkation                    True
# Life Boat                              True
# Survived                              False
# Label                                 False
# dtype: bool

# %%
df[:2]
# Out:
#   Passenger Class                            Name     Sex     Age  \
# 0           First   Allen, Miss. Elisabeth Walton  Female 29.0000
# 1           First  Allison, Master. Hudson Trevor    Male  0.9167
#
#    No of Siblings or Spouses on Board  No of Parents or Children on Board  \
# 0                                   0                                   0
# 1                                   1                                   2
#
#   Ticket Number  Passenger Fare    Cabin Port of Embarkation Life Boat  \
# 0         24160        211.3375       B5         Southampton         2
# 1        113781        151.5500  C22 C26         Southampton        11
#
#   Survived  Label
# 0      Yes   True
# 1      Yes  False

# %%
df['Age'].isnull().sum()
# Out:
# 263

# %%
df['Passenger Fare'].isnull().sum()
# Out:
# 1

# %%
df['Cabin'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304     True
# 1305     True
# 1306     True
# 1307     True
# 1308     True
# Name: Cabin, Length: 1309, dtype: bool

# %%
df
# Out:
#      Passenger Class                                             Name     Sex  \
# 0              First                    Allen, Miss. Elisabeth Walton  Female
# 1              First                   Allison, Master. Hudson Trevor    Male
# 2              First                     Allison, Miss. Helen Loraine  Female
# 3              First             Allison, Mr. Hudson Joshua Creighton    Male
# 4              First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# ...              ...                                              ...     ...
# 1304           Third                             Zabour, Miss. Hileni  Female
# 1305           Third                            Zabour, Miss. Thamine  Female
# 1306           Third                        Zakarian, Mr. Mapriededer    Male
# 1307           Third                              Zakarian, Mr. Ortin    Male
# 1308           Third                               Zimmerman, Mr. Leo    Male
#
# ...

# %%
df_clean = df
df_clean = df_clean.drop('Cabin',1)
df_clean = df_clean.drop('Ticket Number',1)
df_clean
# Out:
#      Passenger Class                                             Name     Sex  \
# 0              First                    Allen, Miss. Elisabeth Walton  Female
# 1              First                   Allison, Master. Hudson Trevor    Male
# 2              First                     Allison, Miss. Helen Loraine  Female
# 3              First             Allison, Mr. Hudson Joshua Creighton    Male
# 4              First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# ...              ...                                              ...     ...
# 1304           Third                             Zabour, Miss. Hileni  Female
# 1305           Third                            Zabour, Miss. Thamine  Female
# 1306           Third                        Zakarian, Mr. Mapriededer    Male
# 1307           Third                              Zakarian, Mr. Ortin    Male
# 1308           Third                               Zimmerman, Mr. Leo    Male
#
# ...

# %%
df_clean = df_clean.dropna(1,'any')
df_clean = df_clean.dropna(0,'any')
df_clean
# Out:
#      Passenger Class                                             Name     Sex  \
# 0              First                    Allen, Miss. Elisabeth Walton  Female
# 1              First                   Allison, Master. Hudson Trevor    Male
# 2              First                     Allison, Miss. Helen Loraine  Female
# 3              First             Allison, Mr. Hudson Joshua Creighton    Male
# 4              First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# ...              ...                                              ...     ...
# 1304           Third                             Zabour, Miss. Hileni  Female
# 1305           Third                            Zabour, Miss. Thamine  Female
# 1306           Third                        Zakarian, Mr. Mapriededer    Male
# 1307           Third                              Zakarian, Mr. Ortin    Male
# 1308           Third                               Zimmerman, Mr. Leo    Male
#
# ...

# %%
df_clean.isnull().any()
# Out:
# Passenger Class                       False
# Name                                  False
# Sex                                   False
# No of Siblings or Spouses on Board    False
# No of Parents or Children on Board    False
# Survived                              False
# Label                                 False
# dtype: bool

# %%
df_clean['Sex'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df_clean['Sex'] = df_clean['Sex'].replace('Female','F')
df_clean['Sex'] = df_clean['Sex'].replace('Male','M')
df_clean
# Out:
#      Passenger Class                                             Name Sex  \
# 0              First                    Allen, Miss. Elisabeth Walton   F
# 1              First                   Allison, Master. Hudson Trevor   M
# 2              First                     Allison, Miss. Helen Loraine   F
# 3              First             Allison, Mr. Hudson Joshua Creighton   M
# 4              First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...              ...                                              ...  ..
# 1304           Third                             Zabour, Miss. Hileni   F
# 1305           Third                            Zabour, Miss. Thamine   F
# 1306           Third                        Zakarian, Mr. Mapriededer   M
# 1307           Third                              Zakarian, Mr. Ortin   M
# 1308           Third                               Zimmerman, Mr. Leo   M
#
#       No of Siblings or Spouses on Board  No of Parents or Children on Board  \
# ...

# %%
p_class, levels = pd.factorize(df_clean['Passenger Class'])

# %%
p_class
# Out:
# array([0, 0, 0, ..., 2, 2, 2])

# %%
levels
# Out:
# Index(['First', 'Second', 'Third'], dtype='object')

# %%
df_clean['Passenger Class'] = p_class
df_clean
# Out:
#       Passenger Class                                             Name Sex  \
# 0                   0                    Allen, Miss. Elisabeth Walton   F
# 1                   0                   Allison, Master. Hudson Trevor   M
# 2                   0                     Allison, Miss. Helen Loraine   F
# 3                   0             Allison, Mr. Hudson Joshua Creighton   M
# 4                   0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...               ...                                              ...  ..
# 1304                2                             Zabour, Miss. Hileni   F
# 1305                2                            Zabour, Miss. Thamine   F
# 1306                2                        Zakarian, Mr. Mapriededer   M
# 1307                2                              Zakarian, Mr. Ortin   M
# 1308                2                               Zimmerman, Mr. Leo   M
#
# ...

# %%
df_clean.dtypes
# Out:
# Passenger Class                        int64
# Name                                  object
# Sex                                   object
# No of Siblings or Spouses on Board     int64
# No of Parents or Children on Board     int64
# Survived                              object
# Label                                   bool
# dtype: object

# %%
df_clean['Sex'] = pd.factorize(df_clean['Sex'])[0]
df_clean['Survived'] = pd.factorize(df_clean['Survived'])[0]
df_clean.dtypes
# Out:
# Passenger Class                        int64
# Name                                  object
# Sex                                    int64
# No of Siblings or Spouses on Board     int64
# No of Parents or Children on Board     int64
# Survived                               int64
# Label                                   bool
# dtype: object

# %%
df_clean = df_clean.set_index('Name')
df_clean
# Out:
#                                                  Passenger Class  Sex  \
# Name
# Allen, Miss. Elisabeth Walton                                  0    0
# Allison, Master. Hudson Trevor                                 0    1
# Allison, Miss. Helen Loraine                                   0    0
# Allison, Mr. Hudson Joshua Creighton                           0    1
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)                0    0
# ...                                                          ...  ...
# Zabour, Miss. Hileni                                           2    0
# Zabour, Miss. Thamine                                          2    0
# Zakarian, Mr. Mapriededer                                      2    1
# Zakarian, Mr. Ortin                                            2    1
# Zimmerman, Mr. Leo                                             2    1
#
#                                                  No of Siblings or Spouses on Board  \
# Name
# ...

# %%
pd.crosstab(df_clean['Passenger Class'],df_clean['Survived']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Passenger Class'>

# %% [markdown]
# > **EX1**

# %%
#EX1.1
cn = pd.read_csv('https://raw.githubusercontent.com/plenoi/Clinic/master/ultima_all_clean.csv', header = 0)

cn = cn.set_index('hn')

cn
# Out:
#          age  parity    hiv  menopaus  disease  surgery  conization  OPDsize  \
# hn
# 2631840   52       3 0.0000    0.0000        1        1      0.0000   5.0000
# 2633481   32       2 0.0000    0.0000        0        1      0.0000   5.0000
# 2634477   52       2 0.0000    0.0000        0        0      0.0000   5.0000
# 2633633   38       2 0.0000    0.0000        0        0      0.0000   2.0000
# 2630496   55       3 0.0000    1.0000        0        0      1.0000   0.0000
# ...      ...     ...    ...       ...      ...      ...         ...      ...
# 3169688   47       2 0.0000    0.0000        0        0      1.0000   0.0000
# 3167041   39       1 0.0000    0.0000        0        0      1.0000   0.0000
# 2623351   46       2 0.0000    0.0000        0        0      1.0000   0.0000
# 3302539   44       3 0.0000    0.0000        0        1      1.0000   0.0000
# 3855674   38       2 0.0000    0.0000        0        0      0.0000   3.0000
#
# ...

# %%
cn['age'].min()
# Out:
# 22

# %%
cn_clean = cn
cn_clean
# Out:
#          age  parity    hiv  menopaus  disease  surgery  conization  OPDsize  \
# hn
# 2631840   52       3 0.0000    0.0000        1        1      0.0000   5.0000
# 2633481   32       2 0.0000    0.0000        0        1      0.0000   5.0000
# 2634477   52       2 0.0000    0.0000        0        0      0.0000   5.0000
# 2633633   38       2 0.0000    0.0000        0        0      0.0000   2.0000
# 2630496   55       3 0.0000    1.0000        0        0      1.0000   0.0000
# ...      ...     ...    ...       ...      ...      ...         ...      ...
# 3169688   47       2 0.0000    0.0000        0        0      1.0000   0.0000
# 3167041   39       1 0.0000    0.0000        0        0      1.0000   0.0000
# 2623351   46       2 0.0000    0.0000        0        0      1.0000   0.0000
# 3302539   44       3 0.0000    0.0000        0        1      1.0000   0.0000
# 3855674   38       2 0.0000    0.0000        0        0      0.0000   3.0000
#
# ...

# %%
#EX1.2
cn_clean = cn_clean.dropna(0,'any')
cn_clean = cn_clean.dropna(1,'any')


cn_clean
# Out:
#          age  parity    hiv  menopaus  disease  surgery  conization  OPDsize  \
# hn
# 2631840   52       3 0.0000    0.0000        1        1      0.0000   5.0000
# 2633481   32       2 0.0000    0.0000        0        1      0.0000   5.0000
# 2633633   38       2 0.0000    0.0000        0        0      0.0000   2.0000
# 2630496   55       3 0.0000    1.0000        0        0      1.0000   0.0000
# 2450167   67       5 0.0000    1.0000        1        0      0.0000   3.0000
# ...      ...     ...    ...       ...      ...      ...         ...      ...
# 3812011   57       2 0.0000    1.0000        1        1      1.0000   0.0000
# 3813471   42       2 0.0000    0.0000        1        0      0.0000   3.0000
# 3812935   53       1 0.0000    1.0000        1        0      1.0000   0.0000
# 3169688   47       2 0.0000    0.0000        0        0      1.0000   0.0000
# 3855674   38       2 0.0000    0.0000        0        0      0.0000   3.0000
#
# ...

# %%
#hiv, size, utmet, vgmet, surgery, pchemo
#EX1.3
cn_clean  = cn_clean .drop('hiv',1)
cn_clean  = cn_clean .drop('size',1)
cn_clean  = cn_clean .drop('utmet',1)
cn_clean  = cn_clean .drop('vgmet',1)
cn_clean  = cn_clean .drop('surgery',1)
cn_clean  = cn_clean .drop('pchemo',1)
cn_clean
# Out:
#          age  parity  menopaus  disease  conization  OPDsize  appearance  \
# hn
# 2631840   52       3    0.0000        1      0.0000   5.0000      4.0000
# 2633481   32       2    0.0000        0      0.0000   5.0000      1.0000
# 2633633   38       2    0.0000        0      0.0000   2.0000      1.0000
# 2630496   55       3    1.0000        0      1.0000   0.0000      5.0000
# 2450167   67       5    1.0000        1      0.0000   3.0000      2.0000
# ...      ...     ...       ...      ...         ...      ...         ...
# 3812011   57       2    1.0000        1      1.0000   0.0000      5.0000
# 3813471   42       2    0.0000        1      0.0000   3.0000      2.0000
# 3812935   53       1    1.0000        1      1.0000   0.0000      5.0000
# 3169688   47       2    0.0000        0      1.0000   0.0000      5.0000
# 3855674   38       2    0.0000        0      0.0000   3.0000      4.0000
#
#          stage  Wardsize  finalhisto  nodeyiel   RHlvsi  depth  vgmargin  \
# hn
# ...

# %%
pd.options.display.float_format = "{:,.0f}".format
cn_clean
# Out:
#          age  parity  menopaus  disease  conization  OPDsize  appearance  \
# hn
# 2631840   52       3         0        1           0        5           4
# 2633481   32       2         0        0           0        5           1
# 2633633   38       2         0        0           0        2           1
# 2630496   55       3         1        0           1        0           5
# 2450167   67       5         1        1           0        3           2
# ...      ...     ...       ...      ...         ...      ...         ...
# 3812011   57       2         1        1           1        0           5
# 3813471   42       2         0        1           0        3           2
# 3812935   53       1         1        1           1        0           5
# 3169688   47       2         0        0           1        0           5
# 3855674   38       2         0        0           0        3           4
#
#          stage  Wardsize  finalhisto  nodeyiel  RHlvsi  depth  vgmargin  \
# hn
# ...

# %%
#EX1.4
old_con = cn_clean['age'] > 20
cn_clean['age'] = old_con

# %%
#EX1.4
cn_clean['age'] = cn_clean['age'].replace(False,'Young')
cn_clean['age'] = cn_clean['age'].replace(True,'Old')
cn_clean
# Out:
#          age  parity  menopaus  disease  conization  OPDsize  appearance  \
# hn
# 2631840  Old       3         0        1           0        5           4
# 2633481  Old       2         0        0           0        5           1
# 2633633  Old       2         0        0           0        2           1
# 2630496  Old       3         1        0           1        0           5
# 2450167  Old       5         1        1           0        3           2
# ...      ...     ...       ...      ...         ...      ...         ...
# 3812011  Old       2         1        1           1        0           5
# 3813471  Old       2         0        1           0        3           2
# 3812935  Old       1         1        1           1        0           5
# 3169688  Old       2         0        0           1        0           5
# 3855674  Old       2         0        0           0        3           4
#
#          stage  Wardsize  finalhisto  nodeyiel  RHlvsi  depth  vgmargin  \
# hn
# ...

# %%
cn_clean['age'].unique()
# Out:
# array(['Old'], dtype=object)

# %%
cn_clean2 = cn_clean
cn_clean2
# Out:
#          age  parity  menopaus  disease  conization  OPDsize  appearance  \
# hn
# 2631840  Old       3         0        1           0        5           4
# 2633481  Old       2         0        0           0        5           1
# 2633633  Old       2         0        0           0        2           1
# 2630496  Old       3         1        0           1        0           5
# 2450167  Old       5         1        1           0        3           2
# ...      ...     ...       ...      ...         ...      ...         ...
# 3812011  Old       2         1        1           1        0           5
# 3813471  Old       2         0        1           0        3           2
# 3812935  Old       1         1        1           1        0           5
# 3169688  Old       2         0        0           1        0           5
# 3855674  Old       2         0        0           0        3           4
#
#          stage  Wardsize  finalhisto  nodeyiel  RHlvsi  depth  vgmargin  \
# hn
# ...

# %%
#EX1.5 And #EX1.6
cn_clean3= cn_clean2.groupby('pmmet').head(10)
cn_clean3.sort_values(by=['pmmet'])
# Out:
#          age  parity  menopaus  disease  conization  OPDsize  appearance  \
# hn
# 2631840  Old       3         0        1           0        5           4
# 2638990  Old       1         0        0           0        2           1
# 2636103  Old       2         0        0           1        0           5
# 2639340  Old       3         0        0           0        4           1
# 2633001  Old       2         0        1           0        2           1
# 743801   Old       1         0        0           1        4           2
# 2450167  Old       5         1        1           0        3           2
# 2630496  Old       3         1        0           1        0           5
# 2633633  Old       2         0        0           0        2           1
# 2633481  Old       2         0        0           0        5           1
# 2677880  Old       1         0        0           1        0           5
# 2634755  Old       2         0        0           0        4           4
# ...

# %%
#Ex 2
pd.crosstab(cn_clean['age'],cn_clean['disease']).plot(kind='bar')
pd.crosstab(cn_clean['age'],cn_clean['conization']).plot(kind='bar')
pd.crosstab(cn_clean['age'],cn_clean['finalhisto']).plot(kind='bar')
pd.crosstab(cn_clean['age'],cn_clean['pelvicme']).plot(kind='bar')
pd.crosstab(cn_clean['age'],cn_clean['pmmet']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='age'>
